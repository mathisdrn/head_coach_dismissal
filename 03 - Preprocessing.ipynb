# %% [markdown]
# ---
# title: Preprocessing
# description: ...
# ---

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
from rich import print
from rich import pretty
pretty.install()
from rich.markdown import Markdown
from rich.table import Table
from rich.panel import Panel
from rich.text import Text
from datetime import datetime

# %%
match_results = pd.read_csv('data/match_results.csv', parse_dates=['date'])
head_coach = pd.read_csv('data/head_coach.csv', parse_dates=['appointed', 'end_date'])

if 'match_url' in match_results.columns:
    match_results.drop(columns = ['match_url'], inplace = True)

# %%
from fuzzywuzzy import process

# Compare team_name in match_results and head_coach
match_team = list(set(match_results['home'].values.tolist() + match_results['away'].values.tolist()))
head_team = head_coach['team_name'].unique().tolist()
# we care about matching team that has been through a change of head coach
# hence we need to match team that are present in head_team but not in match_team

def match_names(name, list_names, min_score=0):
    scores = process.extract(name, list_names, limit=1)
    
    if len(scores) > 0 and scores[0][1] >= min_score:
        return scores[0][0]
    return None

name_match = {}

# Pour chaque nom dans la liste de noms
for team in head_team:
    match = match_names(team, match_team, min_score=70)
    if match is not None:
        name_match[team] = match
    else:
        name_match[team] = None
        print(f"No match found for {team}")

name_match['Inter Milan'] = 'Inter'
name_match['AC Milan'] = 'Milan'
name_match['Stade Rennais FC'] = 'Rennes'
print(name_match)
# Looks correct

# Ensure everything map
for team in head_team:
    if team not in name_match:
        print(team)

# Map head_coach['team_name'] with name_match
head_coach['team_name'] = head_coach['team_name'].map(name_match)
# Out:
# No match found for Stade Rennais FC
# {
#     'Manchester City': 'Manchester City',
#     'Liverpool FC': 'Liverpool',
#     'Chelsea FC': 'Chelsea',
#     'Tottenham Hotspur': 'Tottenham',
#     'Manchester United': 'Manchester Utd',
#     'Arsenal FC': 'Arsenal',
#     'Everton FC': 'Everton',
#     'West Ham United': 'West Ham',
#     'AFC Bournemouth': 'Bournemouth',
#     'Wolverhampton Wanderers': 'Wolves',
#     'Crystal Palace': 'Crystal Palace',
#     'Fulham FC': 'Fulham',
#     'Newcastle United': 'Newcastle Utd',
#     'Burnley FC': 'Burnley',
#     'Brighton & Hove Albion': 'Brighton',
#     'FC Barcelona': 'Barcelona',
#     'Atlético de Madrid': 'Atlético Madrid',
#     'Real Madrid': 'Real Madrid',
#     'Valencia CF': 'Valencia',
#     'Sevilla FC': 'Sevilla',
#     'Real Sociedad': 'Real Sociedad',
#     'Real Betis Balompié': 'Betis',
#     'Athletic Bilbao': 'Athletic Club',
#     'Celta de Vigo': 'Celta Vigo',
#     'Villarreal CF': 'Villarreal',
# ...

# %% [markdown]
# ### To-Do
#
# - investigate NaN values
# - investigate inf and -inf values

# %%
# Save match_results
match_results.to_csv('data/match_results.csv', index=False)
head_coach.to_csv('data/head_coach.csv', index=False)
