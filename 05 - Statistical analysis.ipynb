# %% [markdown]
# ---
# title: Statistical analysis
# description: ...
# ---

# %% [markdown]
# ### Imports

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
from rich import print
from rich import pretty
pretty.install()
from rich.markdown import Markdown
from rich.table import Table
from rich.panel import Panel
from rich.text import Text
from datetime import datetime
# Import utils/utils.py
from utils.utils import filter_team, league_team, team_league, unique_teams, unique_teams_coach_change
# league_team : league -> [team]
# team_league : team -> league
# unique_teams : [all teams]
# unique_teams_coach_change : [all teams that have had a coach change]

# %% [markdown]
# ### Loading data

# %%
match_results = pd.read_csv('data/match_results.csv', parse_dates=['date'])
head_coach = pd.read_csv('data/head_coach.csv', parse_dates=['appointed', 'end_date'])

display(match_results.head())
display(head_coach.head())
# Out:
#            league  country  season_year       date            home  \
# 0  Premier League  England         2018 2017-08-11         Arsenal
# 1  Premier League  England         2018 2017-08-12         Watford
# 2  Premier League  England         2018 2017-08-12  Crystal Palace
# 3  Premier League  England         2018 2017-08-12       West Brom
# 4  Premier League  England         2018 2017-08-12         Chelsea
#
#    home_goals            away  away_goals
# 0         4.0  Leicester City         3.0
# 1         3.0       Liverpool         3.0
# 2         0.0    Huddersfield         3.0
# 3         1.0     Bournemouth         0.0
# 4         2.0         Burnley         3.0
#          team_name          league  country     coach_name  \
# 0  Manchester City  Premier League  England  Pep Guardiola
# 1        Liverpool  Premier League  England   Jürgen Klopp
# 2          Chelsea  Premier League  England  Graham Potter
# 3          Chelsea  Premier League  England  Thomas Tuchel
# ...

# %%
from dataclasses import dataclass
from typing import List, Any

# Let's create a window dataclass, it takes in input head_coach and match_results
@dataclass
class Window:
    head_coach: pd.DataFrame
    match_results: pd.DataFrame
    forward_window: int = 0
    backward_window: int = 0

    def get_data(self):
        """ This method returns all possible set of non_coach_change and coach_change possible within the window
        
        """
        return self.head_coach, self.match_results
    



window = Window(head_coach, match_results, forward_window=100, backward_window=100)
head_coach_change, no_coach_change = window.get_data()
